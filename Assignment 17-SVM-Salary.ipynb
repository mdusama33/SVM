# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV

# %%
train = pd.read_csv('D:\\Data Science\\Assignments\\Assignment 17 (Support Vector Machines)\\SalaryData_Train(1).csv')
train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0            Adm-clerical   Not-in-family   White     Male         2174
# 1         Exec-managerial         Husband   White     Male            0
# 2       Handlers-cleaners   Not-in-family   White     Male            0
# 3       Handlers-cleaners         Husband   Black     Male            0
# 4          Prof-specialty            Wife   Black   Female            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            13   United-States   <=50K
# 2                0            40   United-States   <=50K
# 3                0            40   United-States   <=50K
# 4                0            40            Cuba   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [30161 rows x 14 columns]

# %%
test = pd.read_csv('D:\\Data Science\\Assignments\\Assignment 17 (Support Vector Machines)\\SalaryData_Test(1).csv')
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %%
train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
train.shape
# Out:
# (30161, 14)

# %%
test.shape
# Out:
# (15060, 14)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
train.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
test.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
train.corr()
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.043525     0.080152     0.060278      0.101598
# educationno   0.043525     1.000000     0.124416     0.079691      0.152522
# capitalgain   0.080152     0.124416     1.000000    -0.032218      0.080431
# capitalloss   0.060278     0.079691    -0.032218     1.000000      0.052454
# hoursperweek  0.101598     0.152522     0.080431     0.052454      1.000000

# %%
test.corr()
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.026123     0.078760     0.057745      0.102758
# educationno   0.026123     1.000000     0.131750     0.085817      0.133691
# capitalgain   0.078760     0.131750     1.000000    -0.031876      0.090501
# capitalloss   0.057745     0.085817    -0.031876     1.000000      0.057712
# hoursperweek  0.102758     0.133691     0.090501     0.057712      1.000000

# %%
# Data Processing
lb = LabelEncoder()

# %%
train["workclass"] = lb.fit_transform(train["workclass"])
train["education"] = lb.fit_transform(train["education"])
train["maritalstatus"] = lb.fit_transform(train["maritalstatus"])
train["occupation"] = lb.fit_transform(train["occupation"])
train["relationship"] = lb.fit_transform(train["relationship"])
train["race"] = lb.fit_transform(train["race"])
train["sex"] = lb.fit_transform(train["sex"])
train["native"] = lb.fit_transform(train["native"])
train["Salary"] = lb.fit_transform(train["Salary"])

# %%
test["workclass"] = lb.fit_transform(test["workclass"])
test["education"] = lb.fit_transform(test["education"])
test["maritalstatus"] = lb.fit_transform(test["maritalstatus"])
test["occupation"] = lb.fit_transform(test["occupation"])
test["relationship"] = lb.fit_transform(test["relationship"])
test["race"] = lb.fit_transform(test["race"])
test["sex"] = lb.fit_transform(test["sex"])
test["native"] = lb.fit_transform(test["native"])
test["Salary"] = lb.fit_transform(test["Salary"])

# %%
# EDA
train = train.iloc[: 2000, :]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            2000 non-null   int64
#  1   workclass      2000 non-null   int32
#  2   education      2000 non-null   int32
#  3   educationno    2000 non-null   int64
#  4   maritalstatus  2000 non-null   int32
#  5   occupation     2000 non-null   int32
#  6   relationship   2000 non-null   int32
#  7   race           2000 non-null   int32
#  8   sex            2000 non-null   int32
#  9   capitalgain    2000 non-null   int64
#  10  capitalloss    2000 non-null   int64
#  11  hoursperweek   2000 non-null   int64
#  12  native         2000 non-null   int32
#  13  Salary         2000 non-null   int32
# dtypes: int32(9), int64(5)
# memory usage: 148.6 KB

# %%
train = train.iloc[: 2000, :]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  int64
#  2   education      15060 non-null  int64
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  int64
#  5   occupation     15060 non-null  int64
#  6   relationship   15060 non-null  int64
#  7   race           15060 non-null  int64
#  8   sex            15060 non-null  int64
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  int64
#  13  Salary         15060 non-null  int64
# dtypes: int64(14)
# memory usage: 1.6 MB

# %%
for i in train.describe().columns[:-2]:
    train.plot.scatter(i,'workclass',grid=True)

# %%
for i in train.describe().columns[:-2]:
    train.plot.scatter(i,'occupation',grid=True)

# %%
for i in train.describe().columns[:-2]:
    train.plot.scatter(i,'education',grid=True)

# %%
train.corr()
# Out:
#                     age  workclass  education  educationno  maritalstatus  \
# age            1.000000   0.080136  -0.004007     0.014781      -0.249467
# workclass      0.080136   1.000000   0.029167     0.068866      -0.043219
# education     -0.004007   0.029167   1.000000     0.328746      -0.047668
# educationno    0.014781   0.068866   0.328746     1.000000      -0.062303
# maritalstatus -0.249467  -0.043219  -0.047668    -0.062303       1.000000
# occupation    -0.004634   0.033209  -0.028564     0.098459       0.075036
# relationship  -0.216588  -0.074186  -0.033833    -0.091217       0.157226
# race           0.015168   0.074418   0.031098     0.075867      -0.083280
# sex            0.050730   0.087332  -0.004879     0.034123      -0.078456
# capitalgain    0.081112   0.038314   0.035363     0.095804      -0.044395
# capitalloss    0.058997  -0.003069   0.012082     0.062601      -0.016550
# hoursperweek   0.114429   0.031221   0.060470     0.172302      -0.187437
# native        -0.001914  -0.036263   0.085718     0.057602       0.002006
# Salary         0.231176   0.064561   0.051282     0.308324      -0.199289
#
#                occupation  relationship      race       sex  capitalgain  \
# age             -0.004634     -0.216588  0.015168  0.050730     0.081112
# workclass        0.033209     -0.074186  0.074418  0.087332     0.038314
# education       -0.028564     -0.033833  0.031098 -0.004879     0.035363
# educationno      0.098459     -0.091217  0.075867  0.034123     0.095804
# maritalstatus    0.075036      0.157226 -0.083280 -0.078456    -0.044395
# occupation       1.000000     -0.065478  0.035830  0.072483     0.016453
# relationship    -0.065478      1.000000 -0.100663 -0.557999    -0.052849
# race             0.035830     -0.100663  1.000000  0.076281     0.018565
# sex              0.072483     -0.557999  0.076281  1.000000     0.030977
# capitalgain      0.016453     -0.052849  0.018565  0.030977     1.000000
# workclass         0.010242      0.052614 -0.003635  0.011008
# education         0.020568      0.062892  0.077065  0.085554
# educationno       0.085817      0.133691  0.097188  0.327813
# maritalstatus    -0.034073     -0.171665 -0.016532 -0.191058
# occupation        0.016580      0.011755 -0.001311  0.046218
# relationship     -0.048091     -0.261905  0.000500 -0.258335
# race              0.015799      0.037125  0.125514  0.069227
# sex               0.045360      0.231744 -0.014178  0.213863
# capitalgain      -0.031876      0.090501  0.005923  0.220882
# capitalloss       1.000000      0.057712 -0.001008  0.145967
# hoursperweek      0.057712      1.000000  0.005877  0.222665
# native           -0.001008      0.005877  1.000000  0.014056
# Salary            0.145967      0.222665  0.014056  1.000000

# %%
sns.pairplot(test)

# %%
X_train=train.iloc[:,:-1]
X_train
# Out:
#       age  workclass  education  educationno  maritalstatus  occupation  \
# 0      39          5          9           13              4           0
# 1      50          4          9           13              2           3
# 2      38          2         11            9              0           5
# 3      53          2          1            7              2           5
# 4      28          2          9           13              2           9
# ...   ...        ...        ...          ...            ...         ...
# 1995   33          2         11            9              5          10
# 1996   41          2         11            9              2           6
# 1997   51          2          6            5              2          13
# 1998   42          2         11            9              2          11
# 1999   27          2          9           13              2           9
#
#       relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0                1     4    1         2174            0            40      37
# 1                0     4    1            0            0            13      37
# 2                1     4    1            0            0            40      37
# 3                0     2    1            0            0            40      37
# 4                5     2    0            0            0            40       4
# ...            ...   ...  ...          ...          ...           ...     ...
# 1995             3     4    0            0            0            40      37
# 1996             0     4    1            0            0            40      37
# 1997             0     4    1            0            0            40      37
# 1998             0     4    1            0            0            48      37
# 1999             5     4    0            0            0            40      37
#
# [2000 rows x 13 columns]

# %%
y_train=train.iloc[:,-1]
y_train
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    1
# Name: Salary, Length: 2000, dtype: int32

# %%
X_test=test.iloc[:,:-1]
X_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0                 3     2    1            0            0            40      37
# 1                 0     4    1            0            0            50      37
# 2                 0     4    1            0            0            40      37
# 3                 0     2    1         7688            0            40      37
# 4                 1     4    1            0            0            30      37
# ...             ...   ...  ...          ...          ...           ...     ...
# 15055             3     4    1            0            0            40      37
# 15056             1     4    0            0            0            36      37
# 15057             0     4    1            0            0            50      37
# 15058             3     1    1         5455            0            40      37
# 15059             0     4    1            0            0            60      37
#
# [15060 rows x 13 columns]

# %%
y_test = test.iloc[:,-1]
y_test
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 15055    0
# 15056    0
# 15057    0
# 15058    0
# 15059    1
# Name: Salary, Length: 15060, dtype: int64

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2000, 13), (2000,), (15060, 13), (15060,))

# %%
# SVM
model = SVC()

model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[11319    41]
#  [ 3063   637]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88     11360
#            1       0.94      0.17      0.29      3700
#
#     accuracy                           0.79     15060
#    macro avg       0.86      0.58      0.59     15060
# weighted avg       0.82      0.79      0.73     15060

# %%
# Improving Model using Grid Search CV
param_grid = {'C' : [1, 5, 10, 15, 20], 'gamma' : [1, 0.1, 0.01, 0.001, 0.0001], 'kernel' : ['rbf']}

# %%
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,  cv = 5)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.752 total time=   0.8s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.750 total time=   0.9s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.745 total time=   0.8s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.745 total time=   0.9s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.743 total time=   0.9s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.748 total time=   0.6s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.738 total time=   0.6s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.738 total time=   0.7s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.755 total time=   0.6s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.748 total time=   0.6s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.775 total time=   0.6s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.805 total time=   0.5s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.812 total time=   0.5s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.805 total time=   0.4s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.802 total time=   0.4s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.802 total time=   0.3s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.818 total time=   0.3s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.802 total time=   0.3s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.807 total time=   0.3s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.4s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 1/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.748 total time=   0.9s
# [CV 2/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.745 total time=   0.9s
# [CV 3/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.743 total time=   0.8s
# [CV 4/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.750 total time=   0.9s
# [CV 5/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.750 total time=   0.8s
# [CV 1/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.728 total time=   0.7s
# [CV 2/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.730 total time=   0.7s
# [CV 3/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.730 total time=   0.7s
# [CV 4/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.738 total time=   0.7s
# [CV 5/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.733 total time=   0.7s
# [CV 1/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.782 total time=   0.5s
# [CV 2/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.807 total time=   0.5s
# [CV 3/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.815 total time=   0.4s
# [CV 4/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.810 total time=   0.4s
# [CV 5/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.800 total time=   0.4s
# [CV 1/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.802 total time=   0.3s
# [CV 2/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 3/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 4/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 5/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 1/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.800 total time=   0.3s
# [CV 2/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.807 total time=   0.3s
# [CV 3/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 4/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.818 total time=   0.4s
# [CV 5/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0
# [CV 3/5] END ....C=15, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 4/5] END ....C=15, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.4s
# [CV 5/5] END ....C=15, gamma=0.0001, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 1/5] END .........C=20, gamma=1, kernel=rbf;, score=0.748 total time=   0.8s
# [CV 2/5] END .........C=20, gamma=1, kernel=rbf;, score=0.745 total time=   1.0s
# [CV 3/5] END .........C=20, gamma=1, kernel=rbf;, score=0.743 total time=   0.8s
# [CV 4/5] END .........C=20, gamma=1, kernel=rbf;, score=0.750 total time=   0.9s
# [CV 5/5] END .........C=20, gamma=1, kernel=rbf;, score=0.750 total time=   0.8s
# [CV 1/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.723 total time=   0.7s
# [CV 2/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.730 total time=   0.7s
# [CV 3/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.725 total time=   0.7s
# [CV 4/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.745 total time=   0.7s
# [CV 5/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.738 total time=   0.7s
# [CV 1/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.767 total time=   0.5s
# [CV 2/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.807 total time=   0.5s
# [CV 3/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.787 total time=   0.5s
# [CV 4/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.802 total time=   0.5s
# [CV 5/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.785 total time=   0.5s
# [CV 1/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.4s
# [CV 2/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.818 total time=   0.3s
# [CV 3/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.825 total time=   0.4s
# [CV 4/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.810 total time=   0.4s
# [CV 5/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.823 total time=   0.4s
# [CV 1/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.800 total time=   0.5s
# [CV 2/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.807 total time=   0.4s
# [CV 3/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 4/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.818 total time=   0.3s
# [CV 5/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.3s
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 15, 20],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 15, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
grid_pred = grid.predict(X_test)

# %%
# Model Evaluation
grid_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
print(confusion_matrix(y_test, grid_pred))
# Out:
# [[11064   296]
#  [ 2273  1427]]

# %%
print(confusion_matrix(y_test, grid_pred))
# Out:
# [[11064   296]
#  [ 2273  1427]]
